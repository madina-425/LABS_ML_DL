# %% [markdown]
# task6/ calculating the mean square error

# %%
import kagglehub
import pandas as pd
import os

path = kagglehub.dataset_download("spscientist/students-performance-in-exams")
print(os.listdir(path))
df = pd.read_csv(f"{path}/StudentsPerformance.csv")
df

# %%
math = df['math score'].values 
reading = df['reading score'].values 
writing = df['writing score'].values

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

X=np.array([math,reading]).T
y = np.array(writing)

reg = LinearRegression()
reg = reg.fit(X,y)

y_pred = reg.predict(X)

rmse = np.sqrt(mean_squared_error(y,y_pred))
r2 = reg.score(X, y)

print(rmse,r2)
# Out:
# 4.486483709602601 0.9127415011170787
