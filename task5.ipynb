# %% [markdown]
# Task5. build neural network to recognize handwritten digits from 0-9.

# %%
import numpy as np 
import pandas as pd
from sklearn.datasets import fetch_openml 
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense 
from tensorflow.keras.activations import linear,relu,sigmoid

# %%
X,y = fetch_openml('mnist_784', version=1,return_X_y=True, as_frame=False)

# %%
y = y.astype(np.int32)
X = X.astype('float32') / 255.0

X_train,X_test = X[:60000],X[60000:]
y_train,y_test = y[:60000],y[60000:]

# %%
tf.random.set_seed(1234)
model=Sequential(
    [Dense(128,activation='relu',name='layer1'),
    Dense(64,activation='relu',name='layer2'),
    Dense(10,activation='linear',name='layer3')]
)

model.compile(
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer = tf.keras.optimizers.Adam(0.01),
    metrics = ['accuracy']
)

# %%
model.fit(X_train,y_train,epochs=30)
# Out:
# Epoch 1/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 780us/step - accuracy: 0.9225 - loss: 0.2658
# Epoch 2/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 687us/step - accuracy: 0.9496 - loss: 0.1836
# Epoch 3/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 677us/step - accuracy: 0.9574 - loss: 0.1573
# Epoch 4/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 762us/step - accuracy: 0.9635 - loss: 0.1367
# Epoch 5/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 654us/step - accuracy: 0.9661 - loss: 0.1322
# Epoch 6/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 560us/step - accuracy: 0.9670 - loss: 0.1303
# Epoch 7/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 761us/step - accuracy: 0.9682 - loss: 0.1205
# Epoch 8/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 621us/step - accuracy: 0.9720 - loss: 0.1164
# Epoch 9/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 623us/step - accuracy: 0.9726 - loss: 0.1066
# Epoch 10/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 664us/step - accuracy: 0.9729 - loss: 0.1131
# Epoch 11/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 733us/step - accuracy: 0.9771 - loss: 0.0933
# Epoch 12/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 606us/step - accuracy: 0.9768 - loss: 0.0955
# Epoch 13/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 681us/step - accuracy: 0.9758 - loss: 0.0994
# Epoch 14/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 663us/step - accuracy: 0.9766 - loss: 0.0965
# Epoch 15/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 721us/step - accuracy: 0.9773 - loss: 0.0936
# Epoch 16/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 680us/step - accuracy: 0.9782 - loss: 0.0892
# Epoch 17/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.9790 - loss: 0.0856
# Epoch 18/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 766us/step - accuracy: 0.9775 - loss: 0.0973
# Epoch 19/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 724us/step - accuracy: 0.9806 - loss: 0.0814
# Epoch 20/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 741us/step - accuracy: 0.9803 - loss: 0.0813
# Epoch 21/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 673us/step - accuracy: 0.9792 - loss: 0.0919
# Epoch 22/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - accuracy: 0.9808 - loss: 0.0807
# Epoch 23/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 817us/step - accuracy: 0.9805 - loss: 0.0825
# Epoch 24/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 769us/step - accuracy: 0.9794 - loss: 0.0895
# Epoch 25/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 576us/step - accuracy: 0.9813 - loss: 0.0859
# Epoch 26/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 748us/step - accuracy: 0.9834 - loss: 0.0722
# Epoch 27/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 583us/step - accuracy: 0.9816 - loss: 0.0831
# Epoch 28/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 781us/step - accuracy: 0.9802 - loss: 0.0885
# Epoch 29/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 799us/step - accuracy: 0.9817 - loss: 0.0786
# Epoch 30/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 782us/step - accuracy: 0.9798 - loss: 0.0961

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ layer1 (Dense)                  │ (32, 128)              │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer2 (Dense)                  │ (32, 64)               │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer3 (Dense)                  │ (32, 10)               │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 328,160 (1.25 MB)
#  Trainable params: 109,386 (427.29 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 218,774 (854.59 KB)

# %%
test_loss, test_accuracy = model.evaluate(X_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - accuracy: 0.9678 - loss: 0.2490
# 0.24896371364593506 0.9678000211715698
